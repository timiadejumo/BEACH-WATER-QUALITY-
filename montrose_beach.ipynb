# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('white')

# %%
df = pd.read_csv('~/Downloads/bwq.csv',parse_dates=True,index_col='Measurement Timestamp')

# %%
df
# Out:
#                               Beach Name  Water Temperature  Turbidity  \
# Measurement Timestamp
# 2013-08-30 08:00:00       Montrose Beach               20.3       1.18
# 2016-05-26 13:00:00    Ohio Street Beach               14.4       1.23
# 2013-09-03 16:00:00        Calumet Beach               23.2       3.63
# 2014-05-28 12:00:00        Calumet Beach               16.2       1.26
# 2014-05-28 12:00:00       Montrose Beach               14.4       3.36
# ...                                  ...                ...        ...
# 2017-09-12 12:00:00    Ohio Street Beach               19.9       2.61
# 2017-09-12 13:00:00    Ohio Street Beach               19.8       0.00
# 2017-09-12 15:00:00    Ohio Street Beach               22.3       0.00
# 2017-09-12 17:00:00    Ohio Street Beach               21.1      26.97
# 2017-09-12 18:00:00    Ohio Street Beach               21.3      27.55
#
#                        Transducer Depth  Wave Height  Wave Period  \
# Measurement Timestamp
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 34923 entries, 2013-08-30 08:00:00 to 2017-09-12 18:00:00
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Beach Name                   34923 non-null  object
#  1   Water Temperature            34917 non-null  float64
#  2   Turbidity                    34917 non-null  float64
#  3   Transducer Depth             10034 non-null  float64
#  4   Wave Height                  34690 non-null  float64
#  5   Wave Period                  34690 non-null  float64
#  6   Battery Life                 34917 non-null  float64
#  7   Measurement Timestamp Label  34917 non-null  object
#  8   Measurement ID               34923 non-null  object
# dtypes: float64(6), object(3)
# memory usage: 2.7+ MB

# %%
df.describe()
# Out:
#        Water Temperature     Turbidity  Transducer Depth   Wave Height  \
# count       34917.000000  34917.000000      10034.000000  34690.000000
# mean           19.363387      4.823575          1.570235  -1516.116166
# std             3.356908     33.506600          0.175118  12220.244835
# min             0.000000      0.000000         -0.082000 -99999.992000
# 25%            17.100000      0.660000          1.426000      0.110000
# 50%            19.600000      1.260000          1.578000      0.154000
# 75%            22.000000      2.540000          1.721000      0.201000
# max            31.500000   1683.480000          2.214000      1.467000
#
#          Wave Period  Battery Life
# count   34690.000000  34917.000000
# mean    -1512.482041     11.038205
# std     12220.696864      0.771769
# min   -100000.000000      4.800000
# 25%         3.000000     10.600000
# 50%         3.000000     11.000000
# 75%         4.000000     11.500000
# max        10.000000     13.300000

# %%
fig = plt.gcf()

# Change seaborn plot size
fig.set_size_inches(15, 8)

sns.relplot(y='Turbidity',x='Water Temperature',data=df, hue='Beach Name');

# %%
df = df.drop(columns='Transducer Depth').dropna()

# %%
montrose_df = df[df['Beach Name'] == 'Montrose Beach']
montrose_df
# Out:
#                            Beach Name  Water Temperature  Turbidity  \
# Measurement Timestamp
# 2013-08-30 08:00:00    Montrose Beach               20.3       1.18
# 2014-05-28 12:00:00    Montrose Beach               14.4       3.36
# 2014-05-28 13:00:00    Montrose Beach               14.5       2.72
# 2014-05-28 14:00:00    Montrose Beach               14.8       2.97
# 2014-05-28 15:00:00    Montrose Beach               14.5       4.30
# ...                               ...                ...        ...
# 2016-09-14 15:00:00    Montrose Beach               21.7       0.02
# 2016-09-14 16:00:00    Montrose Beach               21.8       0.00
# 2016-09-14 17:00:00    Montrose Beach               22.0       0.01
# 2016-09-14 18:00:00    Montrose Beach               22.0       0.10
# 2016-09-14 19:00:00    Montrose Beach               21.9       0.01
#
#                        Wave Height  Wave Period  Battery Life  \
# Measurement Timestamp
# ...

# %%
montrose_df.plot(x='Turbidity', style='.b', figsize=(15,8));

# %%
montrose_ts = montrose_df['Turbidity']

montrose_ts
# Out:
# Measurement Timestamp
# 2013-08-30 08:00:00    1.18
# 2014-05-28 12:00:00    3.36
# 2014-05-28 13:00:00    2.72
# 2014-05-28 14:00:00    2.97
# 2014-05-28 15:00:00    4.30
#                        ...
# 2016-09-14 15:00:00    0.02
# 2016-09-14 16:00:00    0.00
# 2016-09-14 17:00:00    0.01
# 2016-09-14 18:00:00    0.10
# 2016-09-14 19:00:00    0.01
# Name: Turbidity, Length: 7268, dtype: float64

# %%
montrose_ts.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Measurement Timestamp'>

# %% [markdown]
# There looks to be an obvious spike in turbidity between months 5 and 9 every year: the height of the Chicago rainy season?

# %%
montrose_ts['2014/01':'2014/09'].plot()
# Out:
# <AxesSubplot:xlabel='Measurement Timestamp'>

# %%
montrose_ts_diff = montrose_ts.diff(periods=12)

# %%
montrose_ts_diff['2014/06'].plot();
